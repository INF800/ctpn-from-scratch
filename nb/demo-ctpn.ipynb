# %%
# !rm -rf ctpn-from-scratch
# !git clone https://github.com/rakesh4real/ctpn-from-scratch
# Out:
# Cloning into 'ctpn-from-scratch'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 26 (delta 0), reused 2 (delta 0), pack-reused 23
# Unpacking objects: 100% (26/26), done.

# %%
# !ls
# Out:
# ctpn-from-scratch  sample_data

# %%
# %cd ctpn-from-scratch/
# Out:
# /content/ctpn-from-scratch

# %%
# !ls
# Out:
# annotation   config.py	    debug	      images	 requirements.txt
# annotations  ctpn_model.py  detect.py	      LICENSE	 train.py
# checkpoints  ctpn_utils.py  icdar_dataset.py  README.md

# %%
from detect import get_det_boxes
import cv2
from google.colab.patches import cv2_imshow

# %%
img_path = "/content/drive/MyDrive/igenesys/ocr/testImagesOCR/2.jpg"
image = cv2.imread(img_path)

# %%
text, img0, img1 = get_det_boxes(image)

# %%
print(text)
cv2_imshow(img0)
# Out:
# [[387.879442   370.9745187  473.         369.55000591 389.
#   422.20000648 474.120558   420.7754937    0.85024321]]
# <PIL.Image.Image image mode=RGB size=1440x720 at 0x7FA0EA0C4C18>
